# %%
import pandas as pd
df_test = pd.read_csv("project-6-at-2022-03-30-11-58-94d689bd.csv")
df_test = df_test[["text", "sentiment"]]

# %%
rslt_df = df_test.loc[df_test['sentiment'] == 'Offensive'] 
rslt_df
# Out:
#                         text  sentiment
# 0              然後都說自己是底賤黃種猴子  Offensive
# 1    這些猴子不管進哪所大學，都是危害社會的隱性毒瘤  Offensive
# 4                      哪來的猴子  Offensive
# 6                   劉懷謙猴子愛看腿  Offensive
# 7                     根本就是猴子  Offensive
# ..                       ...        ...
# 393                 中天不意外哈哈哈  Offensive
# 394                哈哈哈幹零娘，北七  Offensive
# 395         樑筱聆許俊誠一如往常的低能哈哈哈  Offensive
# 396            不給錢就不算嫖囉，哇哈哈哈  Offensive
# 398           你也是一樣是老妖怪啦，哈哈哈  Offensive
#
# [81 rows x 2 columns]

# %%
rslt_df = df_test.loc[df_test['sentiment'] == 'Non-offensive'] 
rslt_df
# Out:
#                         text      sentiment
# 2                  廖靜宜別再餵猴子了  Non-offensive
# 3         不是，別這樣詆毀猴子，猴子是很聰明的  Non-offensive
# 15              臺灣最美麗的風景，是狼性  Non-offensive
# 16                 臺灣最美麗的風景線  Non-offensive
# 17               臺灣最美麗的風景就是人  Non-offensive
# ..                       ...            ...
# 387                  中天，不意外啊  Non-offensive
# 388                    中天不意外  Non-offensive
# 391  不意外啊，國民黨下臺後要做的事就是給全臺扯後腿  Non-offensive
# 397  可以先有試用期嗎，我不會暈船而且認真上進哈哈哈  Non-offensive
# 399              可能鴕鳥生病了吧哈哈哈  Non-offensive
#
# [81 rows x 2 columns]

# %%
rslt_df = df_test.loc[df_test['sentiment'] == 'Very offensive'] 
rslt_df
# Out:
#                                text       sentiment
# 5                             媽的死猴子  Very offensive
# 136                          妓女中之妓女  Very offensive
# 138                         他們比妓女還賤  Very offensive
# 139                     還錢啊欠錢不還啊垃圾人  Very offensive
# 142   所以我說你們這些記者是垃圾，每餐看這些新聞配飯吃的也是垃圾  Very offensive
# 143    不敢回覆捏，跟舔韓智障一樣不敢回覆捏舔韓智障就是舔柯垃圾  Very offensive
# 150                        垃圾一個去死好嗎  Very offensive
# 152                          操你支那賤畜  Very offensive
# 154               所以我說這些支那餘孽和信眾都是垃圾  Very offensive
# 155     看笑到腦死吃屎智障塔莉版狗奴4%支那賤畜檳榔粉氣到吃屎  Very offensive
# 156      放著讓柯屁展示支那賤畜一家親有多智障下賤孬種無能來敗  Very offensive
# 157             怪被說支那賤畜一家親全家吃屎一輩子智障  Very offensive
# 158      拼命大哭免得屎都沒得吃，塔利班狗奴支那賤畜4％＆屎衛  Very offensive
# 159      所以買房干買不起花生糖的支那賤畜屎衛兵什麼事呢？ 批  Very offensive
# 161               難怪吃著屎當塔利班狗奴支那賤畜囉～  Very offensive
# 162            人家塔利班狗奴支那賤畜減刑仔有扛業績的～  Very offensive
# 215                        孫文自己就是廢物  Very offensive
# ...

# %%
rslt_df = df_test.loc[df_test['sentiment'] == 'Very non-offensive'] 
rslt_df
# Out:
#                                text           sentiment
# 9                           夜舒心健康美麗  Very non-offensive
# 10                        嶽虹美女，心情美麗  Very non-offensive
# 11                     嶽虹姊姊午安週末愉快美麗  Very non-offensive
# 12                         美麗的虹姐早安啊  Very non-offensive
# 13                       美麗的虹姐情人節快樂  Very non-offensive
# ..                              ...                 ...
# 312                 忽然很高興呂律師是我老公的友人  Very non-offensive
# 313            選完了沒小商人好寂寞好高興小商人又回來了  Very non-offensive
# 314  看到國民黨這麼多的年輕人，而且形象非常清新，真是高興快樂快樂  Very non-offensive
# 322         是的，喜憨兒城餐坊，麵包就是好吃香味兒滿溢加油  Very non-offensive
# 323                一步一腳印喜憨兒要給他們無私的愛  Very non-offensive
#
# [187 rows x 2 columns]
