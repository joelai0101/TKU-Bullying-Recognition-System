# %%
# IMPORT NECESSARY LIBRARIES
from tensorflow.keras.models import load_model
import librosa
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
from IPython.display import Audio
import numpy as np
import tensorflow as tf
from matplotlib.pyplot import specgram
import pandas as pd
from sklearn.metrics import confusion_matrix
import IPython.display as ipd  # To play sound in the notebook
import os # interface with underlying OS that python is running on
import sys
import warnings
# ignore warnings 
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from tensorflow.keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization, Dense
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
model = load_model("models/Emotion_Model_aug.h5")
# Out:
# Metal device set to: Apple M1 Pro
# 2022-04-21 22:05:27.619746: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-21 22:05:27.619869: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import os, glob

test_path_list = []
for file in glob.glob("./datasets/augmented/upset/*wav"):
    test_path_list.append(file)

# %%
test_path_list
# Out:
# ['./datasets/augmented/upset/data_noise01_padding_看到我是不會打招呼哦 廢物.wav',
#  './datasets/augmented/upset/data_shift16_padding_你不幫我買東西 我就不跟你當朋友 拜託.wav',
#  './datasets/augmented/upset/data_shift32_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你以為這樣子很厲害嗎.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (75).wav',
#  './datasets/augmented/upset/data_shift16_padding_胖子少吃點我都快被你吃垮了.wav',
#  './datasets/augmented/upset/data_pitch08_padding_為什麼要打我.wav',
#  './datasets/augmented/upset/data_speed09_padding_可不可以坐好 一直扭來扭去的.wav',
#  './datasets/augmented/upset/data_speed11_padding_你再不乖乖吃飯我只好就讓你身首異處.wav',
#  './datasets/augmented/upset/data_pitch09_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_shift16_padding_可以請你安靜嗎 我在讀書.wav',
#  './datasets/augmented/upset/data_shift32_padding_你不會動腦嗎.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (82).wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (33).wav',
#  './datasets/augmented/upset/data_noise01_padding_為什麼要打我.wav',
#  './datasets/augmented/upset/data_pitch11_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_shift48_padding_我頭很痛 不要在我耳邊大吼大叫.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (5).wav',
#  './datasets/augmented/upset/data_shift48_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_shift32_padding_我明明作業都有交 老師還叫我罰寫.wav',
#  './datasets/augmented/upset/data_noise05_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (15).wav',
#  './datasets/augmented/upset/data_speed12_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_shift48_padding_我想要抄你的作業 可以嗎.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (11).wav',
#  './datasets/augmented/upset/data_pitch11_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_speed12_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (17).wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (4).wav',
#  './datasets/augmented/upset/data_pitch12_padding_這麼簡單的事你盡然都不會.wav',
#  './datasets/augmented/upset/data_pitch09_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_speed09_padding_我想要抄你的作業 可以嗎.wav',
#  './datasets/augmented/upset/data_speed12_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (8).wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (17).wav',
#  './datasets/augmented/upset/data_speed09_padding_我求求你不要再拉我頭髮了 我真的很抱歉 不要再打我了.wav',
#  './datasets/augmented/upset/data_speed11_padding_這麼簡單的事你盡然都不會.wav',
#  './datasets/augmented/upset/data_noise05_padding_不要在教室追逐 死小鬼.wav',
#  './datasets/augmented/upset/data_pitch08_padding_我求求你不要再拉我頭髮了 我真的很抱歉 不要再打我了.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (3).wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (33).wav',
#  './datasets/augmented/upset/data_speed08_padding_我明明有讀書.wav',
#  './datasets/augmented/upset/data_pitch11_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你也太厲害了吧.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (75).wav',
#  './datasets/augmented/upset/data_pitch11_padding_你再這樣我要叫警察來來把你抓走嘍.wav',
#  './datasets/augmented/upset/data_pitch12_padding_拜託 不要再打了.wav',
#  './datasets/augmented/upset/data_noise05_padding_書讀這麼多 結果還考這麼差.wav',
#  './datasets/augmented/upset/data_pitch08_padding_不要在欺負我了 好嗎.wav',
#  './datasets/augmented/upset/data_pitch08_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_speed12_padding_不要再欺負他了.wav',
#  './datasets/augmented/upset/data_noise005_padding_你爸媽怎麼教你的啊 連這都不會.wav',
#  './datasets/augmented/upset/data_speed12_padding_為什麼只叫我罰站.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (7).wav',
#  './datasets/augmented/upset/data_noise05_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_pitch11_padding_你爸媽怎麼教你的啊 連這都不會.wav',
#  './datasets/augmented/upset/data_shift32_padding_你這樣子做 很好玩嗎.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (83).wav',
#  './datasets/augmented/upset/data_shift16_padding_為什麼只叫我罰站.wav',
#  './datasets/augmented/upset/data_pitch09_padding_拜託 借我一點錢 好嗎.wav',
#  './datasets/augmented/upset/data_speed09_padding_你好壞喔.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (83).wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (78).wav',
#  './datasets/augmented/upset/data_shift16_padding_他明明也有跟我一起玩 為什麼老師沒有罵他.wav',
#  './datasets/augmented/upset/data_noise05_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_speed11_padding_你們這樣罵我 會遭天譴的.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (16).wav',
#  './datasets/augmented/upset/data_noise005_padding_不要在教室追逐 死小鬼.wav',
#  './datasets/augmented/upset/data_noise005_padding_不要再欺負他了.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (81).wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (11).wav',
#  './datasets/augmented/upset/data_pitch12_padding_你們這樣罵我 會遭天譴的.wav',
#  './datasets/augmented/upset/data_noise01_padding_不要再欺負他了.wav',
#  './datasets/augmented/upset/data_shift16_padding_我明明作業都有交 老師還叫我罰寫.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (41).wav',
#  './datasets/augmented/upset/data_pitch08_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_pitch09_padding_可以請你安靜嗎 我在讀書.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (39).wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (33).wav',
#  './datasets/augmented/upset/data_noise01_padding_怎麼每一次考試都不及格阿.wav',
#  './datasets/augmented/upset/data_shift48_padding_總有一天 你會得到報應的.wav',
#  './datasets/augmented/upset/data_shift32_padding_你們這樣罵我 會遭天譴的.wav',
#  './datasets/augmented/upset/data_shift16_padding_你這樣真的很糟糕.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (80).wav',
#  './datasets/augmented/upset/data_speed08_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_speed11_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_speed09_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_pitch09_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_noise05_padding_你怎麼長的那麼奇怪.wav',
#  './datasets/augmented/upset/data_noise01_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (7).wav',
#  './datasets/augmented/upset/data_noise05_padding_你怎麼會這麼笨.wav',
#  './datasets/augmented/upset/data_pitch12_padding_拜託 不要再哭了.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (79).wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_pitch11_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_shift16_padding_你也太厲害了吧.wav',
#  './datasets/augmented/upset/data_noise005_padding_你一定不是你媽親生的 你的臉看起來就像被壓路機壓過.wav',
#  './datasets/augmented/upset/data_speed09_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_speed12_padding_你爸媽怎麼教你的啊 連這都不會.wav',
#  './datasets/augmented/upset/data_shift16_padding_讀那麼久書還考那麼爛 真沒用.wav',
#  './datasets/augmented/upset/data_speed12_padding_你這樣真的很糟糕.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (9).wav',
#  './datasets/augmented/upset/data_pitch11_padding_你不幫我買東西 我就不跟你當朋友 拜託.wav',
#  './datasets/augmented/upset/data_speed09_padding_什麼事都做不好 你只是一個窩囊廢.wav',
#  './datasets/augmented/upset/data_pitch11_padding_不要拿我東西.wav',
#  './datasets/augmented/upset/data_speed08_padding_怎麼每一次考試都不及格阿.wav',
#  './datasets/augmented/upset/data_pitch09_padding_幹你他媽怎麼能長得那麼醜.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (6).wav',
#  './datasets/augmented/upset/data_speed12_padding_什麼事都做不好 你只是一個窩囊廢.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (8).wav',
#  './datasets/augmented/upset/data_pitch09_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_noise01_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_speed12_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (4).wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (77).wav',
#  './datasets/augmented/upset/data_speed09_padding_不要再欺負他了.wav',
#  './datasets/augmented/upset/data_speed11_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (79).wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_speed09_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你也太厲害了吧.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (83).wav',
#  './datasets/augmented/upset/data_shift32_padding_不要在欺負我了 好嗎.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (80).wav',
#  './datasets/augmented/upset/data_noise01_padding_你好壞喔.wav',
#  './datasets/augmented/upset/data_speed09_padding_總有一天 你會得到報應的.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (3).wav',
#  './datasets/augmented/upset/data_noise05_padding_不要拿我東西.wav',
#  './datasets/augmented/upset/data_pitch08_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (17).wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (14).wav',
#  './datasets/augmented/upset/data_shift32_padding_這麼簡單的事你盡然都不會.wav',
#  './datasets/augmented/upset/data_noise05_padding_怎麼每一次考試都不及格阿.wav',
#  './datasets/augmented/upset/data_speed12_padding_為什麼要打我.wav',
#  './datasets/augmented/upset/data_speed11_padding_不要再欺負他了.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你這樣子做 很好玩嗎.wav',
#  './datasets/augmented/upset/data_speed08_padding_我頭很痛 不要在我耳邊大吼大叫.wav',
#  './datasets/augmented/upset/data_speed12_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_pitch11_padding_你也太厲害了吧.wav',
#  './datasets/augmented/upset/data_shift16_padding_幹你他媽怎麼能長得那麼醜.wav',
#  './datasets/augmented/upset/data_pitch11_padding_他明明也有跟我一起玩 為什麼老師沒有罵他.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (2).wav',
#  './datasets/augmented/upset/data_pitch11_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_speed11_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_noise05_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_shift32_padding_你不幫我買東西 我就不跟你當朋友 拜託.wav',
#  './datasets/augmented/upset/data_speed12_padding_你以為這樣子很厲害嗎.wav',
#  './datasets/augmented/upset/data_speed11_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_pitch12_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_speed08_padding_不要再欺負他了.wav',
#  './datasets/augmented/upset/data_noise01_padding_胖子少吃點我都快被你吃垮了.wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (6).wav',
#  './datasets/augmented/upset/data_shift16_padding_看到我是不會打招呼哦 廢物.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你也太厲害了吧.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你的字怎麼這麼醜啊.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (14).wav',
#  './datasets/augmented/upset/data_speed12_padding_你的字怎麼這麼醜啊.wav',
#  './datasets/augmented/upset/data_pitch12_padding_我明明有讀書.wav',
#  './datasets/augmented/upset/data_noise05_padding_你是眼瞎嗎 走路不會看路哦.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_noise05_padding_不要再欺負他了.wav',
#  './datasets/augmented/upset/data_noise005_padding_你再不乖乖吃飯我只好就讓你身首異處.wav',
#  './datasets/augmented/upset/data_speed09_padding_你是眼瞎嗎 走路不會看路哦.wav',
#  './datasets/augmented/upset/data_shift32_padding_讀那麼久書還考那麼爛 真沒用.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (15).wav',
#  './datasets/augmented/upset/data_speed12_padding_怎麼每一次考試都不及格阿.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (77).wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (7).wav',
#  './datasets/augmented/upset/data_speed08_padding_拜託 借我一點錢 好嗎.wav',
#  './datasets/augmented/upset/data_speed11_padding_為什麼要打我.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_pitch11_padding_怎麼每一次考試都不及格阿.wav',
#  './datasets/augmented/upset/data_speed11_padding_什麼事都做不好 你只是一個窩囊廢.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (77).wav',
#  './datasets/augmented/upset/data_shift48_padding_看到我是不會打招呼哦 廢物.wav',
#  './datasets/augmented/upset/data_pitch11_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (3).wav',
#  './datasets/augmented/upset/data_speed08_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (71).wav',
#  './datasets/augmented/upset/data_speed12_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_speed09_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_pitch11_padding_我明明有讀書.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (41).wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (75).wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (15).wav',
#  './datasets/augmented/upset/data_pitch09_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_pitch11_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_noise005_padding_我想要抄你的作業 可以嗎.wav',
#  './datasets/augmented/upset/data_pitch08_padding_我明明作業都有交 老師還叫我罰寫.wav',
#  './datasets/augmented/upset/data_speed08_padding_你再不乖乖吃飯我只好就讓你身首異處.wav',
#  './datasets/augmented/upset/data_noise05_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你這個又醜又胖的四眼田雞.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (2).wav',
#  './datasets/augmented/upset/data_speed09_padding_你怎麼會這麼笨.wav',
#  './datasets/augmented/upset/data_speed12_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_noise05_padding_你再這樣我要叫警察來來把你抓走嘍.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (16).wav',
#  './datasets/augmented/upset/data_pitch09_padding_看到我是不會打招呼哦 廢物.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (81).wav',
#  './datasets/augmented/upset/data_shift16_padding_你這個又醜又胖的四眼田雞.wav',
#  './datasets/augmented/upset/data_noise05_padding_你再不乖乖吃飯我只好就讓你身首異處.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_speed11_padding_我頭很痛 不要在我耳邊大吼大叫.wav',
#  './datasets/augmented/upset/data_shift48_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你怎麼長的那麼奇怪.wav',
#  './datasets/augmented/upset/data_pitch12_padding_不要拿我東西.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (78).wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (82).wav',
#  './datasets/augmented/upset/data_speed09_padding_你怎麼長的那麼奇怪.wav',
#  './datasets/augmented/upset/data_pitch09_padding_可不可以坐好 一直扭來扭去的.wav',
#  './datasets/augmented/upset/data_speed11_padding_你以為這樣子很厲害嗎.wav',
#  './datasets/augmented/upset/data_shift32_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (9).wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (5).wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (39).wav',
#  './datasets/augmented/upset/data_shift32_padding_他明明也有跟我一起玩 為什麼老師沒有罵他.wav',
#  './datasets/augmented/upset/data_speed11_padding_你怎麼會這麼笨.wav',
#  './datasets/augmented/upset/data_noise01_padding_什麼事都做不好 你只是一個窩囊廢.wav',
#  './datasets/augmented/upset/data_pitch09_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_pitch08_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (7).wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (71).wav',
#  './datasets/augmented/upset/data_speed08_padding_你怎麼會這麼笨.wav',
#  './datasets/augmented/upset/data_noise05_padding_你好壞喔.wav',
#  './datasets/augmented/upset/data_speed12_padding_拜託 不要再哭了.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (8).wav',
#  './datasets/augmented/upset/data_pitch11_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (39).wav',
#  './datasets/augmented/upset/data_pitch11_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_speed08_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你這樣真的很糟糕.wav',
#  './datasets/augmented/upset/data_pitch09_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (6).wav',
#  './datasets/augmented/upset/data_noise01_padding_不要在教室追逐 死小鬼.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (78).wav',
#  './datasets/augmented/upset/data_noise05_padding_我頭很痛 不要在我耳邊大吼大叫.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_noise05_padding_我明明有讀書.wav',
#  './datasets/augmented/upset/data_speed11_padding_他明明也有跟我一起玩 為什麼老師沒有罵他.wav',
#  './datasets/augmented/upset/data_shift32_padding_好吵喔 完全讀不了書.wav',
#  './datasets/augmented/upset/data_shift16_padding_拜託 不要再哭了.wav',
#  './datasets/augmented/upset/data_speed09_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (81).wav',
#  './datasets/augmented/upset/data_noise005_padding_我明明作業都有交 老師還叫我罰寫.wav',
#  './datasets/augmented/upset/data_speed08_padding_不要拿我東西.wav',
#  './datasets/augmented/upset/data_shift32_padding_為什麼老師要罵我.wav',
#  './datasets/augmented/upset/data_pitch08_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你再這樣我要叫警察來來把你抓走嘍.wav',
#  './datasets/augmented/upset/data_noise01_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (80).wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (10).wav',
#  './datasets/augmented/upset/data_pitch12_padding_我頭很痛 不要在我耳邊大吼大叫.wav',
#  './datasets/augmented/upset/data_pitch08_padding_這麼簡單的事你盡然都不會.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_pitch11_padding_你好壞喔.wav',
#  './datasets/augmented/upset/data_pitch11_padding_拜託 借我一點錢 好嗎.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (17).wav',
#  './datasets/augmented/upset/data_noise01_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_shift16_padding_我頭很痛 不要在我耳邊大吼大叫.wav',
#  './datasets/augmented/upset/data_shift48_padding_你以為這樣子很厲害嗎.wav',
#  './datasets/augmented/upset/data_noise01_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (33).wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (82).wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (79).wav',
#  './datasets/augmented/upset/data_pitch12_padding_為什麼只叫我罰站.wav',
#  './datasets/augmented/upset/data_speed11_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (33).wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (82).wav',
#  './datasets/augmented/upset/data_noise005_padding_總有一天 你會得到報應的.wav',
#  './datasets/augmented/upset/data_speed08_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_speed09_padding_你不會動腦嗎.wav',
#  './datasets/augmented/upset/data_pitch11_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_speed12_padding_不要在教室追逐 死小鬼.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (6).wav',
#  './datasets/augmented/upset/data_speed12_padding_你怎麼會這麼笨.wav',
#  './datasets/augmented/upset/data_shift32_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你再這樣我要叫警察來來把你抓走嘍.wav',
#  './datasets/augmented/upset/data_shift16_padding_你怎麼沒有一件事做得好啊.wav',
#  './datasets/augmented/upset/data_shift16_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_noise05_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (41).wav',
#  './datasets/augmented/upset/data_noise01_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你一定不是你媽親生的 你的臉看起來就像被壓路機壓過.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你怎麼沒有一件事做得好啊.wav',
#  './datasets/augmented/upset/data_shift48_padding_胖子少吃點我都快被你吃垮了.wav',
#  './datasets/augmented/upset/data_shift16_padding_拜託 不要再打了.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (41).wav',
#  './datasets/augmented/upset/data_speed09_padding_書讀這麼多 結果還考這麼差.wav',
#  './datasets/augmented/upset/data_shift32_padding_我求求你不要再拉我頭髮了 我真的很抱歉 不要再打我了.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (16).wav',
#  './datasets/augmented/upset/data_speed12_padding_拜託 不要再打了.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (2).wav',
#  './datasets/augmented/upset/data_pitch09_padding_胖子少吃點我都快被你吃垮了.wav',
#  './datasets/augmented/upset/data_noise005_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_pitch09_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_shift32_padding_你一定不是你媽親生的 你的臉看起來就像被壓路機壓過.wav',
#  './datasets/augmented/upset/data_pitch12_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (16).wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (5).wav',
#  './datasets/augmented/upset/data_pitch08_padding_你們這樣罵我 會遭天譴的.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你爸媽怎麼教你的啊 連這都不會.wav',
#  './datasets/augmented/upset/data_speed11_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (9).wav',
#  './datasets/augmented/upset/data_speed09_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_shift32_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_noise01_padding_你怎麼會這麼笨.wav',
#  './datasets/augmented/upset/data_shift48_padding_你再不乖乖吃飯我只好就讓你身首異處.wav',
#  './datasets/augmented/upset/data_speed09_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_shift48_padding_我求求你不要再拉我頭髮了 我真的很抱歉 不要再打我了.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (14).wav',
#  './datasets/augmented/upset/data_pitch09_padding_你一定不是你媽親生的 你的臉看起來就像被壓路機壓過.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (10).wav',
#  './datasets/augmented/upset/data_shift32_padding_一定把你鼻梁打歪.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (83).wav',
#  './datasets/augmented/upset/data_noise005_padding_你怎麼會這麼笨.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你再不乖乖吃飯我只好就讓你身首異處.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (4).wav',
#  './datasets/augmented/upset/data_speed11_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_speed09_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (77).wav',
#  './datasets/augmented/upset/data_speed12_padding_你好壞喔.wav',
#  './datasets/augmented/upset/data_noise005_padding_為什麼要打我.wav',
#  './datasets/augmented/upset/data_pitch08_padding_好吵喔 完全讀不了書.wav',
#  './datasets/augmented/upset/data_shift48_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_pitch12_padding_拜託 借我一點錢 好嗎.wav',
#  './datasets/augmented/upset/data_speed08_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_shift48_padding_不要拿我東西.wav',
#  './datasets/augmented/upset/data_speed08_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_pitch11_padding_讀那麼久書還考那麼爛 真沒用.wav',
#  './datasets/augmented/upset/data_speed08_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (81).wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (15).wav',
#  './datasets/augmented/upset/data_noise01_padding_你怎麼長的那麼奇怪.wav',
#  './datasets/augmented/upset/data_speed08_padding_看到我是不會打招呼哦 廢物.wav',
#  './datasets/augmented/upset/data_pitch09_padding_好吵喔 完全讀不了書.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (78).wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (39).wav',
#  './datasets/augmented/upset/data_speed12_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_speed11_padding_你怎麼長的那麼奇怪.wav',
#  './datasets/augmented/upset/data_shift16_padding_為什麼老師要罵我.wav',
#  './datasets/augmented/upset/data_shift48_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_speed08_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_speed08_padding_你好壞喔.wav',
#  './datasets/augmented/upset/data_speed11_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你是眼瞎嗎 走路不會看路哦.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (9).wav',
#  './datasets/augmented/upset/data_speed08_padding_你再這樣我要叫警察來來把你抓走嘍.wav',
#  './datasets/augmented/upset/data_speed11_padding_不要在教室追逐 死小鬼.wav',
#  './datasets/augmented/upset/data_pitch09_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (71).wav',
#  './datasets/augmented/upset/data_pitch11_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (81).wav',
#  './datasets/augmented/upset/data_shift32_padding_什麼事都做不好 你只是一個窩囊廢.wav',
#  './datasets/augmented/upset/data_shift16_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (2).wav',
#  './datasets/augmented/upset/data_speed11_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (14).wav',
#  './datasets/augmented/upset/data_pitch12_padding_我求求你不要再拉我頭髮了 我真的很抱歉 不要再打我了.wav',
#  './datasets/augmented/upset/data_pitch12_padding_可不可以坐好 一直扭來扭去的.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (39).wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (78).wav',
#  './datasets/augmented/upset/data_speed08_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_speed09_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (14).wav',
#  './datasets/augmented/upset/data_speed12_padding_為什麼老師要罵我.wav',
#  './datasets/augmented/upset/data_shift32_padding_不要再欺負他了.wav',
#  './datasets/augmented/upset/data_shift16_padding_一定把你鼻梁打歪.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (5).wav',
#  './datasets/augmented/upset/data_shift48_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (80).wav',
#  './datasets/augmented/upset/data_pitch11_padding_看到我是不會打招呼哦 廢物.wav',
#  './datasets/augmented/upset/data_shift48_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (11).wav',
#  './datasets/augmented/upset/data_pitch08_padding_你這個又醜又胖的四眼田雞.wav',
#  './datasets/augmented/upset/data_shift48_padding_不要在欺負我了 好嗎.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_noise005_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_speed12_padding_你不會動腦嗎.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (80).wav',
#  './datasets/augmented/upset/data_speed12_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (78).wav',
#  './datasets/augmented/upset/data_speed12_padding_他明明也有跟我一起玩 為什麼老師沒有罵他.wav',
#  './datasets/augmented/upset/data_shift32_padding_可以請你安靜嗎 我在讀書.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_speed09_padding_我頭很痛 不要在我耳邊大吼大叫.wav',
#  './datasets/augmented/upset/data_shift16_padding_什麼事都做不好 你只是一個窩囊廢.wav',
#  './datasets/augmented/upset/data_shift16_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_speed12_padding_一定把你鼻梁打歪.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (15).wav',
#  './datasets/augmented/upset/data_noise005_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (4).wav',
#  './datasets/augmented/upset/data_shift32_padding_拜託 不要再打了.wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (81).wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (6).wav',
#  './datasets/augmented/upset/data_pitch12_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_pitch12_padding_幹你他媽怎麼能長得那麼醜.wav',
#  './datasets/augmented/upset/data_noise01_padding_讀那麼久書還考那麼爛 真沒用.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (7).wav',
#  './datasets/augmented/upset/data_speed11_padding_幹你他媽怎麼能長得那麼醜.wav',
#  './datasets/augmented/upset/data_shift32_padding_胖子少吃點我都快被你吃垮了.wav',
#  './datasets/augmented/upset/data_pitch08_padding_可不可以坐好 一直扭來扭去的.wav',
#  './datasets/augmented/upset/data_speed11_padding_你這樣子做 很好玩嗎.wav',
#  './datasets/augmented/upset/data_shift48_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_speed11_padding_你是眼瞎嗎 走路不會看路哦.wav',
#  './datasets/augmented/upset/data_pitch11_padding_總有一天 你會得到報應的.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (79).wav',
#  './datasets/augmented/upset/data_shift16_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (33).wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (39).wav',
#  './datasets/augmented/upset/data_speed12_padding_總有一天 你會得到報應的.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (79).wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (15).wav',
#  './datasets/augmented/upset/data_pitch09_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_noise01_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你不會動腦嗎.wav',
#  './datasets/augmented/upset/data_shift32_padding_看到我是不會打招呼哦 廢物.wav',
#  './datasets/augmented/upset/data_speed11_padding_不要在欺負我了 好嗎.wav',
#  './datasets/augmented/upset/data_noise01_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_speed11_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_shift32_padding_幹你他媽怎麼能長得那麼醜.wav',
#  './datasets/augmented/upset/data_noise01_padding_你不會動腦嗎.wav',
#  './datasets/augmented/upset/data_speed09_padding_他明明也有跟我一起玩 為什麼老師沒有罵他.wav',
#  './datasets/augmented/upset/data_shift32_padding_為什麼要打我.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (3).wav',
#  './datasets/augmented/upset/data_shift16_padding_這麼簡單的事你盡然都不會.wav',
#  './datasets/augmented/upset/data_speed09_padding_你不幫我買東西 我就不跟你當朋友 拜託.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (83).wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (17).wav',
#  './datasets/augmented/upset/data_noise05_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_speed12_padding_我明明作業都有交 老師還叫我罰寫.wav',
#  './datasets/augmented/upset/data_shift48_padding_你這樣子做 很好玩嗎.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (2).wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (11).wav',
#  './datasets/augmented/upset/data_pitch08_padding_不要在教室追逐 死小鬼.wav',
#  './datasets/augmented/upset/data_shift48_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_speed09_padding_我明明作業都有交 老師還叫我罰寫.wav',
#  './datasets/augmented/upset/data_pitch09_padding_不要拿我東西.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (11).wav',
#  './datasets/augmented/upset/data_pitch09_padding_你們這樣罵我 會遭天譴的.wav',
#  './datasets/augmented/upset/data_noise01_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_pitch11_padding_胖子少吃點我都快被你吃垮了.wav',
#  './datasets/augmented/upset/data_shift32_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (5).wav',
#  './datasets/augmented/upset/data_pitch11_padding_你一定不是你媽親生的 你的臉看起來就像被壓路機壓過.wav',
#  './datasets/augmented/upset/data_noise05_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_speed08_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_speed11_padding_可以請你安靜嗎 我在讀書.wav',
#  './datasets/augmented/upset/data_pitch08_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_speed11_padding_書讀這麼多 結果還考這麼差.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你怎麼沒有一件事做得好啊.wav',
#  './datasets/augmented/upset/data_pitch12_padding_可以請你安靜嗎 我在讀書.wav',
#  './datasets/augmented/upset/data_noise005_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_speed08_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_noise005_padding_怎麼每一次考試都不及格阿.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你一定不是你媽親生的 你的臉看起來就像被壓路機壓過.wav',
#  './datasets/augmented/upset/data_shift48_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_pitch11_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (9).wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (8).wav',
#  './datasets/augmented/upset/data_pitch08_padding_你不幫我買東西 我就不跟你當朋友 拜託.wav',
#  './datasets/augmented/upset/data_shift32_padding_拜託 不要再哭了.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (7).wav',
#  './datasets/augmented/upset/data_noise005_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_shift16_padding_你們這樣罵我 會遭天譴的.wav',
#  './datasets/augmented/upset/data_speed09_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (10).wav',
#  './datasets/augmented/upset/data_speed12_padding_我想要抄你的作業 可以嗎.wav',
#  './datasets/augmented/upset/data_shift48_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_pitch09_padding_這麼簡單的事你盡然都不會.wav',
#  './datasets/augmented/upset/data_pitch08_padding_書讀這麼多 結果還考這麼差.wav',
#  './datasets/augmented/upset/data_pitch11_padding_我求求你不要再拉我頭髮了 我真的很抱歉 不要再打我了.wav',
#  './datasets/augmented/upset/data_pitch11_padding_我想要抄你的作業 可以嗎.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (17).wav',
#  './datasets/augmented/upset/data_speed08_padding_你的字怎麼這麼醜啊.wav',
#  './datasets/augmented/upset/data_noise005_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (83).wav',
#  './datasets/augmented/upset/data_shift48_padding_拜託 借我一點錢 好嗎.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (6).wav',
#  './datasets/augmented/upset/data_shift48_padding_你的字怎麼這麼醜啊.wav',
#  './datasets/augmented/upset/data_noise005_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (75).wav',
#  './datasets/augmented/upset/data_shift16_padding_不要拿我東西.wav',
#  './datasets/augmented/upset/data_speed12_padding_好吵喔 完全讀不了書.wav',
#  './datasets/augmented/upset/data_noise05_padding_我求求你不要再拉我頭髮了 我真的很抱歉 不要再打我了.wav',
#  './datasets/augmented/upset/data_speed12_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_noise005_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (75).wav',
#  './datasets/augmented/upset/data_speed11_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_noise005_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_speed08_padding_胖子少吃點我都快被你吃垮了.wav',
#  './datasets/augmented/upset/data_speed11_padding_你怎麼沒有一件事做得好啊.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (41).wav',
#  './datasets/augmented/upset/data_pitch08_padding_什麼事都做不好 你只是一個窩囊廢.wav',
#  './datasets/augmented/upset/data_noise005_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_pitch11_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你怎麼沒有一件事做得好啊.wav',
#  './datasets/augmented/upset/data_pitch08_padding_可以請你安靜嗎 我在讀書.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (16).wav',
#  './datasets/augmented/upset/data_speed08_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_pitch11_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (82).wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (7).wav',
#  './datasets/augmented/upset/data_shift32_padding_你這個又醜又胖的四眼田雞.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (11).wav',
#  './datasets/augmented/upset/data_pitch09_padding_我明明有讀書.wav',
#  './datasets/augmented/upset/data_shift16_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (6).wav',
#  './datasets/augmented/upset/data_speed08_padding_可不可以坐好 一直扭來扭去的.wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (75).wav',
#  './datasets/augmented/upset/data_noise005_padding_我求求你不要再拉我頭髮了 我真的很抱歉 不要再打我了.wav',
#  './datasets/augmented/upset/data_speed12_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_speed11_padding_我明明作業都有交 老師還叫我罰寫.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (9).wav',
#  './datasets/augmented/upset/data_shift48_padding_可不可以坐好 一直扭來扭去的.wav',
#  './datasets/augmented/upset/data_speed09_padding_為什麼要打我.wav',
#  './datasets/augmented/upset/data_noise005_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_shift32_padding_你這樣真的很糟糕.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (8).wav',
#  './datasets/augmented/upset/data_pitch09_padding_他明明也有跟我一起玩 為什麼老師沒有罵他.wav',
#  './datasets/augmented/upset/data_shift32_padding_你爸媽怎麼教你的啊 連這都不會.wav',
#  './datasets/augmented/upset/data_speed12_padding_不要在欺負我了 好嗎.wav',
#  './datasets/augmented/upset/data_shift48_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_speed08_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你這樣子做 很好玩嗎.wav',
#  './datasets/augmented/upset/data_shift16_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_noise05_padding_我想要抄你的作業 可以嗎.wav',
#  './datasets/augmented/upset/data_pitch08_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_shift16_padding_你的字怎麼這麼醜啊.wav',
#  './datasets/augmented/upset/data_shift16_padding_我明明有讀書.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_pitch12_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_speed11_padding_讀那麼久書還考那麼爛 真沒用.wav',
#  './datasets/augmented/upset/data_speed11_padding_好吵喔 完全讀不了書.wav',
#  './datasets/augmented/upset/data_noise05_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_shift16_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (75).wav',
#  './datasets/augmented/upset/data_shift16_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_noise01_padding_我頭很痛 不要在我耳邊大吼大叫.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你是眼瞎嗎 走路不會看路哦.wav',
#  './datasets/augmented/upset/data_noise005_padding_書讀這麼多 結果還考這麼差.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你爸媽怎麼教你的啊 連這都不會.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (10).wav',
#  './datasets/augmented/upset/data_speed08_padding_我想要抄你的作業 可以嗎.wav',
#  './datasets/augmented/upset/data_shift32_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你怎麼長的那麼奇怪.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (4).wav',
#  './datasets/augmented/upset/data_shift16_padding_不要在教室追逐 死小鬼.wav',
#  './datasets/augmented/upset/data_pitch08_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (3).wav',
#  './datasets/augmented/upset/data_noise005_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (10).wav',
#  './datasets/augmented/upset/data_speed08_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (33).wav',
#  './datasets/augmented/upset/data_shift48_padding_你再這樣我要叫警察來來把你抓走嘍.wav',
#  './datasets/augmented/upset/data_noise005_padding_可不可以坐好 一直扭來扭去的.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (82).wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (33).wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (16).wav',
#  './datasets/augmented/upset/data_noise05_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_pitch09_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_noise01_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (75).wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (2).wav',
#  './datasets/augmented/upset/data_noise01_padding_我明明作業都有交 老師還叫我罰寫.wav',
#  './datasets/augmented/upset/data_shift32_padding_你以為這樣子很厲害嗎.wav',
#  './datasets/augmented/upset/data_pitch11_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_noise01_padding_我想要抄你的作業 可以嗎.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (71).wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (41).wav',
#  './datasets/augmented/upset/data_speed12_padding_看到我是不會打招呼哦 廢物.wav',
#  './datasets/augmented/upset/data_noise005_padding_你不會動腦嗎.wav',
#  './datasets/augmented/upset/data_shift48_padding_你一定不是你媽親生的 你的臉看起來就像被壓路機壓過.wav',
#  './datasets/augmented/upset/data_speed12_padding_可不可以坐好 一直扭來扭去的.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (78).wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (14).wav',
#  './datasets/augmented/upset/data_shift32_padding_你的字怎麼這麼醜啊.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你不幫我買東西 我就不跟你當朋友 拜託.wav',
#  './datasets/augmented/upset/data_noise005_padding_你是眼瞎嗎 走路不會看路哦.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (78).wav',
#  './datasets/augmented/upset/data_pitch12_padding_書讀這麼多 結果還考這麼差.wav',
#  './datasets/augmented/upset/data_shift16_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_shift48_padding_好吵喔 完全讀不了書.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_speed12_padding_胖子少吃點我都快被你吃垮了.wav',
#  './datasets/augmented/upset/data_shift16_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_speed09_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_speed11_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (71).wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (7).wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (80).wav',
#  './datasets/augmented/upset/data_speed11_padding_你不會動腦嗎.wav',
#  './datasets/augmented/upset/data_pitch12_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (6).wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (71).wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (39).wav',
#  './datasets/augmented/upset/data_pitch11_padding_你的字怎麼這麼醜啊.wav',
#  './datasets/augmented/upset/data_noise05_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (14).wav',
#  './datasets/augmented/upset/data_noise005_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (5).wav',
#  './datasets/augmented/upset/data_noise05_padding_總有一天 你會得到報應的.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (77).wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (39).wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (79).wav',
#  './datasets/augmented/upset/data_noise05_padding_你不幫我買東西 我就不跟你當朋友 拜託.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_noise05_padding_可不可以坐好 一直扭來扭去的.wav',
#  './datasets/augmented/upset/data_shift48_padding_他明明也有跟我一起玩 為什麼老師沒有罵他.wav',
#  './datasets/augmented/upset/data_pitch12_padding_一定把你鼻梁打歪.wav',
#  './datasets/augmented/upset/data_shift48_padding_我明明有讀書.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (81).wav',
#  './datasets/augmented/upset/data_noise005_padding_什麼事都做不好 你只是一個窩囊廢.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (4).wav',
#  './datasets/augmented/upset/data_pitch08_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (81).wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (10).wav',
#  './datasets/augmented/upset/data_speed09_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (79).wav',
#  './datasets/augmented/upset/data_pitch08_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (15).wav',
#  './datasets/augmented/upset/data_shift48_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_shift48_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_noise005_padding_你怎麼長的那麼奇怪.wav',
#  './datasets/augmented/upset/data_noise005_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_shift32_padding_你怎麼會這麼笨.wav',
#  './datasets/augmented/upset/data_speed08_padding_總有一天 你會得到報應的.wav',
#  './datasets/augmented/upset/data_shift48_padding_你也太厲害了吧.wav',
#  './datasets/augmented/upset/data_pitch12_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (15).wav',
#  './datasets/augmented/upset/data_pitch08_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_speed09_padding_怎麼每一次考試都不及格阿.wav',
#  './datasets/augmented/upset/data_noise01_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_shift16_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_pitch12_padding_為什麼老師要罵我.wav',
#  './datasets/augmented/upset/data_pitch08_padding_幹你他媽怎麼能長得那麼醜.wav',
#  './datasets/augmented/upset/data_pitch09_padding_不要在欺負我了 好嗎.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (80).wav',
#  './datasets/augmented/upset/data_speed09_padding_你再不乖乖吃飯我只好就讓你身首異處.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (3).wav',
#  './datasets/augmented/upset/data_speed12_padding_你這樣子做 很好玩嗎.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (8).wav',
#  './datasets/augmented/upset/data_speed11_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (77).wav',
#  './datasets/augmented/upset/data_shift32_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (79).wav',
#  './datasets/augmented/upset/data_shift32_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_pitch08_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_shift32_padding_你怎麼沒有一件事做得好啊.wav',
#  './datasets/augmented/upset/data_speed09_padding_不要在教室追逐 死小鬼.wav',
#  './datasets/augmented/upset/data_shift32_padding_拜託 借我一點錢 好嗎.wav',
#  './datasets/augmented/upset/data_noise01_padding_總有一天 你會得到報應的.wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (14).wav',
#  './datasets/augmented/upset/data_pitch12_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你以為這樣子很厲害嗎.wav',
#  './datasets/augmented/upset/data_noise01_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_shift48_padding_怎麼每一次考試都不及格阿.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你這個又醜又胖的四眼田雞.wav',
#  './datasets/augmented/upset/data_pitch12_padding_他明明也有跟我一起玩 為什麼老師沒有罵他.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (80).wav',
#  './datasets/augmented/upset/data_pitch11_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_speed09_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_speed11_padding_你這個又醜又胖的四眼田雞.wav',
#  './datasets/augmented/upset/data_shift32_padding_為什麼只叫我罰站.wav',
#  './datasets/augmented/upset/data_pitch11_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_noise05_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (17).wav',
#  './datasets/augmented/upset/data_speed12_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (10).wav',
#  './datasets/augmented/upset/data_speed08_padding_這麼簡單的事你盡然都不會.wav',
#  './datasets/augmented/upset/data_noise01_padding_你這樣真的很糟糕.wav',
#  './datasets/augmented/upset/data_pitch08_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (2).wav',
#  './datasets/augmented/upset/data_shift32_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_speed09_padding_你爸媽怎麼教你的啊 連這都不會.wav',
#  './datasets/augmented/upset/data_pitch09_padding_讀那麼久書還考那麼爛 真沒用.wav',
#  './datasets/augmented/upset/data_noise01_padding_書讀這麼多 結果還考這麼差.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (5).wav',
#  './datasets/augmented/upset/data_noise005_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (8).wav',
#  './datasets/augmented/upset/data_pitch11_padding_為什麼老師要罵我.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (4).wav',
# ...
#  './datasets/augmented/upset/data_pitch08_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (39).wav',
#  './datasets/augmented/upset/data_shift32_padding_你怎麼長的那麼奇怪.wav',
#  './datasets/augmented/upset/data_shift32_padding_你也太厲害了吧.wav',
#  './datasets/augmented/upset/data_pitch12_padding_怎麼每一次考試都不及格阿.wav',
#  './datasets/augmented/upset/data_shift48_padding_你怎麼會這麼笨.wav',
#  './datasets/augmented/upset/data_noise01_padding_你再這樣我要叫警察來來把你抓走嘍.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (77).wav',
#  './datasets/augmented/upset/data_speed08_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (81).wav',
#  './datasets/augmented/upset/data_noise005_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (4).wav',
#  './datasets/augmented/upset/data_shift48_padding_你這個又醜又胖的四眼田雞.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (9).wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (15).wav',
#  './datasets/augmented/upset/data_pitch08_padding_拜託 不要再哭了.wav',
#  './datasets/augmented/upset/data_speed09_padding_你一定不是你媽親生的 你的臉看起來就像被壓路機壓過.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (8).wav',
#  './datasets/augmented/upset/data_speed08_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_shift48_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_speed12_padding_我明明有讀書.wav',
#  './datasets/augmented/upset/data_speed09_padding_為什麼老師要罵我.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_shift48_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_noise005_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_shift32_padding_你好壞喔.wav',
#  './datasets/augmented/upset/data_pitch11_padding_你這樣子做 很好玩嗎.wav',
#  './datasets/augmented/upset/data_pitch11_padding_你怎麼長的那麼奇怪.wav',
#  './datasets/augmented/upset/data_pitch12_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (78).wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (5).wav',
#  './datasets/augmented/upset/data_pitch12_padding_為什麼要打我.wav',
#  './datasets/augmented/upset/data_speed11_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_noise005_padding_為什麼只叫我罰站.wav',
#  './datasets/augmented/upset/data_noise05_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_speed09_padding_你這個又醜又胖的四眼田雞.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (3).wav',
#  './datasets/augmented/upset/data_speed08_padding_你一定不是你媽親生的 你的臉看起來就像被壓路機壓過.wav',
#  './datasets/augmented/upset/data_speed08_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (71).wav',
#  './datasets/augmented/upset/data_noise05_padding_胖子少吃點我都快被你吃垮了.wav',
#  './datasets/augmented/upset/data_noise005_padding_你的字怎麼這麼醜啊.wav',
#  './datasets/augmented/upset/data_speed11_padding_你再這樣我要叫警察來來把你抓走嘍.wav',
#  './datasets/augmented/upset/data_pitch12_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_speed12_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_noise005_padding_你好壞喔.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (7).wav',
#  './datasets/augmented/upset/data_noise01_padding_你是眼瞎嗎 走路不會看路哦.wav',
#  './datasets/augmented/upset/data_noise005_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_shift16_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (78).wav',
#  './datasets/augmented/upset/data_pitch11_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (33).wav',
#  './datasets/augmented/upset/data_pitch08_padding_你好壞喔.wav',
#  './datasets/augmented/upset/data_noise01_padding_不要在欺負我了 好嗎.wav',
#  './datasets/augmented/upset/data_speed09_padding_好吵喔 完全讀不了書.wav',
#  './datasets/augmented/upset/data_noise01_padding_為什麼只叫我罰站.wav',
#  './datasets/augmented/upset/data_shift32_padding_我肚子好痛.wav',
#  './datasets/augmented/upset/data_shift48_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_pitch12_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_noise01_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (15).wav',
#  './datasets/augmented/upset/data_shift48_padding_你這樣真的很糟糕.wav',
#  './datasets/augmented/upset/data_speed09_padding_拜託 借我一點錢 好嗎.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (81).wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (11).wav',
#  './datasets/augmented/upset/data_shift32_padding_不要在教室追逐 死小鬼.wav',
#  './datasets/augmented/upset/data_shift48_padding_你好壞喔.wav',
#  './datasets/augmented/upset/data_noise05_padding_什麼事都做不好 你只是一個窩囊廢.wav',
#  './datasets/augmented/upset/data_pitch11_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_shift16_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (39).wav',
#  './datasets/augmented/upset/data_shift32_padding_沒有腦袋像個智障.wav',
#  './datasets/augmented/upset/data_noise005_padding_可以請你安靜嗎 我在讀書.wav',
#  './datasets/augmented/upset/data_speed11_padding_不要拿我東西.wav',
#  './datasets/augmented/upset/data_shift16_padding_書讀這麼多 結果還考這麼差.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (71).wav',
#  './datasets/augmented/upset/data_pitch12_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_speed08_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_speed09_padding_一定把你鼻梁打歪.wav',
#  './datasets/augmented/upset/data_shift48_padding_不要再欺負他了.wav',
#  './datasets/augmented/upset/data_noise01_padding_你爸媽怎麼教你的啊 連這都不會.wav',
#  './datasets/augmented/upset/data_pitch12_padding_不要在教室追逐 死小鬼.wav',
#  './datasets/augmented/upset/data_shift48_padding_幹你他媽怎麼能長得那麼醜.wav',
#  './datasets/augmented/upset/data_speed12_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_noise05_padding_你這樣子做 很好玩嗎.wav',
#  './datasets/augmented/upset/data_pitch08_padding_為什麼 什麼事情都叫我做.wav',
#  './datasets/augmented/upset/data_pitch09_padding_一定把你鼻梁打歪.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你再不乖乖吃飯我只好就讓你身首異處.wav',
#  './datasets/augmented/upset/data_noise01_padding_好吵喔 完全讀不了書.wav',
#  './datasets/augmented/upset/data_noise01_padding_你的字怎麼這麼醜啊.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (77).wav',
#  './datasets/augmented/upset/data_pitch12_padding_你這樣子做 很好玩嗎.wav',
#  './datasets/augmented/upset/data_shift16_padding_你再不乖乖吃飯我只好就讓你身首異處.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (14).wav',
#  './datasets/augmented/upset/data_shift48_padding_拜託 不要再哭了.wav',
#  './datasets/augmented/upset/data_speed09_padding_不要在欺負我了 好嗎.wav',
#  './datasets/augmented/upset/data_pitch09_padding_我頭很痛 不要在我耳邊大吼大叫.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (80).wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (10).wav',
#  './datasets/augmented/upset/data_speed11_padding_你的字怎麼這麼醜啊.wav',
#  './datasets/augmented/upset/data_speed08_padding_你以為這樣子很厲害嗎.wav',
#  './datasets/augmented/upset/data_pitch09_padding_總有一天 你會得到報應的.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_shift32_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_noise05_padding_為什麼要打我.wav',
#  './datasets/augmented/upset/data_speed12_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_pitch09_padding_書讀這麼多 結果還考這麼差.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (6).wav',
#  './datasets/augmented/upset/data_speed11_padding_拜託 借我一點錢 好嗎.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (79).wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_shift16_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_speed12_padding_不要拿我東西.wav',
#  './datasets/augmented/upset/data_speed12_padding_不要再動手打人了.wav',
#  './datasets/augmented/upset/data_speed12_padding_你不幫我買東西 我就不跟你當朋友 拜託.wav',
#  './datasets/augmented/upset/data_noise005_padding_拜託 不要再打了.wav',
#  './datasets/augmented/upset/data_speed09_padding_胖子少吃點我都快被你吃垮了.wav',
#  './datasets/augmented/upset/data_shift48_padding_書讀這麼多 結果還考這麼差.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (77).wav',
#  './datasets/augmented/upset/data_pitch08_padding_怎麼每一次考試都不及格阿.wav',
#  './datasets/augmented/upset/data_speed09_padding_幹你他媽怎麼能長得那麼醜.wav',
#  './datasets/augmented/upset/data_noise005_padding_你以為這樣子很厲害嗎.wav',
#  './datasets/augmented/upset/data_pitch08_padding_我明明沒有吵鬧 卻還是被老師罵.wav',
#  './datasets/augmented/upset/data_noise01_padding_拜託 不要再打了.wav',
#  './datasets/augmented/upset/data_noise005_padding_你怎麼沒有一件事做得好啊.wav',
#  './datasets/augmented/upset/data_speed11_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_speed11_padding_我明明有讀書.wav',
#  './datasets/augmented/upset/data_noise01_padding_讀書就安靜不要吵鬧.wav',
#  './datasets/augmented/upset/data_speed09_padding_你再這樣我要叫警察來來把你抓走嘍.wav',
#  './datasets/augmented/upset/data_noise05_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (2).wav',
#  './datasets/augmented/upset/data_speed11_padding_我求求你不要再拉我頭髮了 我真的很抱歉 不要再打我了.wav',
#  './datasets/augmented/upset/data_shift16_padding_總有一天 你會得到報應的.wav',
#  './datasets/augmented/upset/data_shift16_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_noise05_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_pitch12_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (77).wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (79).wav',
#  './datasets/augmented/upset/data_speed09_padding_讀那麼久書還考那麼爛 真沒用.wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (4).wav',
#  './datasets/augmented/upset/data_noise01_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_shift48_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_shift48_padding_你不會動腦嗎.wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (13).wav',
#  './datasets/augmented/upset/data_shift48_padding_都給我閉嘴.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (80).wav',
#  './datasets/augmented/upset/data_speed11_padding_re-cry- (5).wav',
#  './datasets/augmented/upset/data_shift32_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (8).wav',
#  './datasets/augmented/upset/data_speed11_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (14).wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (9).wav',
#  './datasets/augmented/upset/data_pitch08_padding_你這樣真的很糟糕.wav',
#  './datasets/augmented/upset/data_speed12_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_noise01_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_pitch09_padding_為什麼老師要罵我.wav',
#  './datasets/augmented/upset/data_speed08_padding_拜託 不要再哭了.wav',
#  './datasets/augmented/upset/data_speed08_padding_為什麼要這樣對待我.wav',
#  './datasets/augmented/upset/data_pitch11_padding_拜託你們 考出好成績好嗎.wav',
#  './datasets/augmented/upset/data_noise005_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_speed12_padding_你再這樣我要叫警察來來把你抓走嘍.wav',
#  './datasets/augmented/upset/data_shift32_padding_我頭很痛 不要在我耳邊大吼大叫.wav',
#  './datasets/augmented/upset/data_pitch11_padding_為什麼要打我.wav',
#  './datasets/augmented/upset/data_shift32_padding_你敢把這些事說出去 就死定了.wav',
#  './datasets/augmented/upset/data_noise005_padding_他明明也有跟我一起玩 為什麼老師沒有罵他.wav',
#  './datasets/augmented/upset/data_speed12_padding_我求求你不要再拉我頭髮了 我真的很抱歉 不要再打我了.wav',
#  './datasets/augmented/upset/data_speed12_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (41).wav',
#  './datasets/augmented/upset/data_pitch12_padding_不要在教室跑來跑去了 好不好.wav',
#  './datasets/augmented/upset/data_noise005_padding_拜託 不要再哭了.wav',
#  './datasets/augmented/upset/data_shift32_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_pitch12_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (2).wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (82).wav',
#  './datasets/augmented/upset/data_pitch08_padding_re-cry- (33).wav',
#  './datasets/augmented/upset/data_pitch11_padding_好吵喔 完全讀不了書.wav',
#  './datasets/augmented/upset/data_speed11_padding_為什麼老天爺要這樣對待我.wav',
#  './datasets/augmented/upset/data_shift32_padding_你可不可以去死阿.wav',
#  './datasets/augmented/upset/data_speed11_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_shift16_padding_你不會動腦嗎.wav',
#  './datasets/augmented/upset/data_pitch08_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_noise05_padding_re-cry- (16).wav',
#  './datasets/augmented/upset/data_speed11_padding_一定把你鼻梁打歪.wav',
#  './datasets/augmented/upset/data_noise005_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_pitch09_padding_re-cry- (75).wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (3).wav',
#  './datasets/augmented/upset/data_shift32_padding_拜託 教我這一題.wav',
#  './datasets/augmented/upset/data_pitch08_padding_拜託 借我一點錢 好嗎.wav',
#  './datasets/augmented/upset/data_speed09_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_speed08_padding_re-cry- (1).wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (82).wav',
#  './datasets/augmented/upset/data_noise005_padding_我明明有讀書.wav',
#  './datasets/augmented/upset/data_shift48_padding_拜託 不要再打了.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (17).wav',
#  './datasets/augmented/upset/data_pitch11_padding_這麼簡單的事你盡然都不會.wav',
#  './datasets/augmented/upset/data_shift16_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_noise005_padding_你這個又醜又胖的四眼田雞.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (17).wav',
#  './datasets/augmented/upset/data_speed12_padding_這麼簡單的事你盡然都不會.wav',
#  './datasets/augmented/upset/data_pitch09_padding_我想要抄你的作業 可以嗎.wav',
#  './datasets/augmented/upset/data_pitch12_padding_明明東西吃這麼少 結果還是很胖.wav',
#  './datasets/augmented/upset/data_pitch08_padding_為什麼只叫我罰站.wav',
#  './datasets/augmented/upset/data_noise05_padding_我明明什麼事情都沒做 還要被唸.wav',
#  './datasets/augmented/upset/data_shift16_padding_可不可以坐好 一直扭來扭去的.wav',
#  './datasets/augmented/upset/data_shift32_padding_re-cry- (12).wav',
#  './datasets/augmented/upset/data_noise01_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_speed12_padding_re-cry- (83).wav',
#  './datasets/augmented/upset/data_pitch12_padding_re-cry- (6).wav',
#  './datasets/augmented/upset/data_speed08_padding_我明明作業都有交 老師還叫我罰寫.wav',
#  './datasets/augmented/upset/data_speed11_padding_你不給我錢 放學後就知道了.wav',
#  './datasets/augmented/upset/data_pitch09_padding_你不會動腦嗎.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (41).wav',
#  './datasets/augmented/upset/data_speed11_padding_為什麼不寫作業.wav',
#  './datasets/augmented/upset/data_pitch11_padding_re-cry- (83).wav',
#  './datasets/augmented/upset/data_shift16_padding_我想要抄你的作業 可以嗎.wav',
#  './datasets/augmented/upset/data_shift48_padding_re-cry- (11).wav',
#  './datasets/augmented/upset/data_speed11_padding_不要玩了 快點讀書.wav',
#  './datasets/augmented/upset/data_speed08_padding_拜託 不要再打了.wav',
#  './datasets/augmented/upset/data_pitch09_padding_這是我的鉛筆 不是你的.wav',
#  './datasets/augmented/upset/data_shift48_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_noise005_padding_re-cry- (71).wav',
#  './datasets/augmented/upset/data_speed09_padding_re-cry- (8).wav',
#  './datasets/augmented/upset/data_shift16_padding_re-cry- (75).wav',
#  './datasets/augmented/upset/data_pitch08_padding_以為有在讀書 實際上整天都在打電動.wav',
#  './datasets/augmented/upset/data_noise01_padding_re-cry- (16).wav',
#  './datasets/augmented/upset/data_speed08_padding_你這什麼態度 看我還不打死你.wav',
#  './datasets/augmented/upset/data_speed09_padding_看到我是不會打招呼哦 廢物.wav',
#  ...]

# %%
def get_features(path):

    X, sample_rate = librosa.load(path, res_type='kaiser_fast', duration=10.0, sr=None)
    
    stft = np.abs(librosa.stft(X))

    # fmin 和 fmax 對應於人類語音的最小最大基本頻率
    pitches, magnitudes = librosa.piptrack(X, sr=sample_rate, S=stft, fmin=70, fmax=400)
    pitch = []
    for i in range(magnitudes.shape[1]):
        index = magnitudes[:, 1].argmax()
        pitch.append(pitches[index, i])

    pitch_tuning_offset = librosa.pitch_tuning(pitches)
    pitchmean = np.mean(pitch)
    pitchstd = np.std(pitch)
    pitchmax = np.max(pitch)
    pitchmin = np.min(pitch)

    # 頻譜質心
    cent = librosa.feature.spectral_centroid(y=X, sr=sample_rate)
    cent = cent / np.sum(cent)
    meancent = np.mean(cent)
    stdcent = np.std(cent)
    maxcent = np.max(cent)

    # 譜平面
    flatness = np.mean(librosa.feature.spectral_flatness(y=X))

    # 使用系數為13的MFCC特徵
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=13).T, axis=0)
    mfccsstd = np.std(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=13).T, axis=0)
    mfccmax = np.max(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=13).T, axis=0)

    # 色譜圖
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)

    # 梅爾頻率
    mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)

    # ottava對比
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T, axis=0)

    # 過零率
    zerocr = np.mean(librosa.feature.zero_crossing_rate(X))

    S, phase = librosa.magphase(stft)
    meanMagnitude = np.mean(S)
    stdMagnitude = np.std(S)
    maxMagnitude = np.max(S)

    # 均方根能量
    rms = librosa.feature.rms(S=S)[0]
    meanrms = np.mean(rms)
    stdrms = np.std(rms)
    maxrms = np.max(rms)

    ext_features = np.array([
        flatness, zerocr, meanMagnitude, maxMagnitude, meancent, stdcent,
        maxcent, stdMagnitude, pitchmean, pitchmax, pitchstd,
        pitch_tuning_offset, meanrms, maxrms, stdrms
    ])

    ext_features = np.concatenate((ext_features, mfccs, mfccsstd, mfccmax, chroma, mel, contrast))
        
    return ext_features

# %%
scaler = StandardScaler()
encoder = OneHotEncoder()

df_features = pd.read_csv('features.csv')
df_features
# Out:
#       labels         0         1         2           3         4         5  \
# 0      taunt  0.349620  0.129026  0.554054  163.037979  0.003195  0.002922
# 1      taunt  0.420087  0.068244  0.560991  167.655838  0.003195  0.002847
# 2      taunt  0.498637  0.081467  0.773144  273.056702  0.003195  0.003458
# 3      taunt  0.648623  0.043919  0.402030  160.456573  0.003195  0.004484
# 4      taunt  0.542116  0.040381  0.373848  106.289726  0.003195  0.003759
# ...      ...       ...       ...       ...         ...       ...       ...
# 15730  upset  0.590074  0.039775  0.060804   64.716248  0.003195  0.004357
# 15731  upset  0.653773  0.028561  0.162391   80.988266  0.003195  0.006068
# 15732  upset  0.558546  0.022143  0.115764   57.101089  0.003195  0.004675
# 15733  upset  0.442611  0.414153  0.293616   58.416603  0.003195  0.000528
# 15734  upset  0.583244  0.061325  0.042297   56.019958  0.003195  0.004181
#
#               6         7          8  ...       191       192           193  \
# 0      0.011338  2.890938  21.750515  ...  0.024860  0.005420  3.369298e-04
# 1      0.011331  2.839539   7.450559  ...  0.002620  0.000413  2.484302e-05
# 2      0.015535  5.216930   6.002203  ...  0.010938  0.002382  1.156494e-04
# 3      0.017506  2.989140   7.426612  ...  0.041246  0.010192  4.100692e-04
# 4      0.016790  2.185241  11.056521  ...  0.017987  0.003564  2.029519e-04
# ...         ...       ...        ...  ...       ...       ...           ...
# 15730  0.021169  0.596097  10.541844  ...  0.000552  0.000190  1.256435e-05
# 15731  0.039710  1.285566   4.347139  ...  0.004041  0.001087  4.006107e-05
# 15732  0.024271  0.994173   0.000000  ...  0.000419  0.000086  6.196451e-06
# 15733  0.003832  0.763809  22.621918  ...  0.010631  0.009824  9.442406e-03
# 15734  0.013974  0.584885  10.136929  ...  0.000022  0.000006  3.889865e-07
#
#              194        195        196        197        198        199  \
# 0      19.080706  19.134450  21.125617  19.423748  19.274803  21.902710
# 1      17.962222  16.911051  17.674325  17.033042  16.880189  19.637548
# 2      16.050520  19.224504  20.094982  19.420473  18.647094  21.973569
# 3      16.558265  16.364409  16.976335  16.284359  16.494198  16.978649
# 4      17.101434  13.360917  14.166413  14.598431  13.997962  14.618500
# ...          ...        ...        ...        ...        ...        ...
# 15730  21.841346  17.680658  18.387753  18.150996  18.145541  19.234715
# 15731  18.034568  15.331230  15.971342  16.239014  16.085378  16.849852
# 15732  18.136612  14.629613  16.083037  15.785649  15.428285  16.005202
# 15733  13.220441  13.531459  14.359092  13.468283  13.740494  13.739564
# 15734  24.767029  20.379361  20.669696  20.558135  22.489451  21.760471
#
#              200
# 0      25.117049
# 1      23.111096
# 2      23.659706
# 3      20.274362
# 4      19.963319
# ...          ...
# 15730  22.864406
# 15731  20.068561
# 15732  19.735171
# 15733  13.453153
# 15734  25.061769
#
# [15735 rows x 202 columns]

# %%
X = df_features.iloc[:, 1:].values
X = scaler.fit_transform(X)
Y = df_features['labels'].values
Y = encoder.fit_transform(np.array(Y).reshape(-1, 1)).toarray()

# %%
for index, element in enumerate(test_path_list):
    df = pd.DataFrame(columns=['features'])
    df.features = get_features(test_path_list[index])
    textfeature_df = pd.DataFrame(df['features'].values.tolist()).T
    X = textfeature_df.iloc[:, :].values
    X = scaler.transform(X)
    X = np.expand_dims(X, axis=2)
    pred_test = model.predict(X)
    pred = encoder.inverse_transform(pred_test)
    print(pred)
# Out:
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['calm']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['calm']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['angry']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['calm']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['taunt']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['calm']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]
# [['upset']]

# %%
# loading json and model architecture 
json_file = open('model_json_aug.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = tf.keras.models.model_from_json(loaded_model_json)

# load weights into new model
loaded_model.load_weights("models/Emotion_Model_aug.h5")
print("Loaded model from disk")

# %%
print(type(Y_pred))
print(Y_pred.item(0))
print(type(Y_pred.item(0)))

# %%
# Keras optimiser
loaded_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
loaded_model.summary()

# %%
import pyaudio
import wave
from datetime import datetime
import speech_recognition as sr

FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 16000
CHUNK = 1024
RECORD_SECONDS = 10
WAVE_OUTPUT_FILENAME = ""

pa = pyaudio.PyAudio()
r = sr.Recognizer()

# %%
stream = pa.open(format=FORMAT, channels=CHANNELS,
                        rate=RATE, input=True, frames_per_buffer=CHUNK, input_device_index=0)
stream.start_stream()
print("開始錄音......")

frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)
print("錄音結束!")

stream.stop_stream()
stream.close()
pa.terminate()

WAVE_OUTPUT_FILENAME = "./record/"+datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+".wav"

wf = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(pa.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()

# %%
with sr.AudioFile(WAVE_OUTPUT_FILENAME) as source:
    audio = r.record(source)

# %%
output_df = pd.DataFrame(columns=['features'])

output_df.features = get_features(WAVE_OUTPUT_FILENAME)

# %%
output_feature_df = pd.DataFrame(output_df['features'].values.tolist()).T

# %%
X = output_feature_df.iloc[:, :].values
X = scaler.fit_transform(X)
X = np.expand_dims(X, axis=2)
pred_test = model.predict(X)

# %%
Y_pred = encoder.inverse_transform(pred_test)
Y_pred
